# %% [markdown]
# # Alan Almaraz - 28/08/2024

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# $$ \sqrt{x^2 + 4} $$

# %%
import sympy as sp

sp.var("x")
def f(x):
    return (x**2 +4 )**0.5
dx = sp.diff(f(x), x) 
pc = sp.solve(dx, x)
print("El punto crítico está en " + str(pc))

x = np.linspace(-10,10,1000)
y = (x**2 + 4)**0.5
plt.figure()
plt.plot(x,y)
plt.grid()
# Out:
# El punto crítico está en [0.0]

# %% [markdown]
# $$ x^2 - 4x + 2 $$

# %%
sp.var("x")
def f(x):
    return (x**2 - 4*x + 2)
dx = sp.diff(f(x), x) 
pc = sp.solve(dx, x)
print("El punto crítico está en " + str(pc))

x = np.linspace(-5,9,100)
y = (x**2 - 4*x + 2)
plt.figure()
plt.plot(x,y)
plt.grid()
# Out:
# El punto crítico está en [2]

# %% [markdown]
# $$ sin(3x) $$

# %%
import matplotlib.pyplot as plt
import numpy as np
def f(x):
    return np.sin(3*x)

x = np.linspace(-5,9,100)
y = np.sin(3*x)
plt.figure()
plt.plot(x,y)
plt.grid()

import sympy as sp
def f(x):
    return sp.sin(3*x)

sp.var("x")
dx = sp.diff(f(x), x) 
pc = sp.solve(dx, x)
print("El punto crítico está en " + str(pc))
# Out:
# El punto crítico está en [pi/6, pi/2]

# %% [markdown]
# $$ e^2x -3 $$

# %%
import sympy as sp
def f(x):
    return ((e**2*x) - 3)

sp.var("x")
dx = sp.diff(f(x), x) 
pc = sp.solve(dx, x)
print("El punto crítico está en " + str(pc))

x = np.linspace(-10,10,100)
y = f(x)
plt.figure()
plt.plot(x,y)
plt.grid()
# Out:
# El punto crítico está en []

# %% [markdown]
# $$ cos(x + \pi/4) $$

# %%
import math as m
import sympy as sp
def f(x):
    return sp.cos(x + m.pi/4)

sp.var("x")
dx = sp.diff(f(x), x) 
pc = sp.solve(dx, x)
print("El punto crítico está en " + str(pc))


import numpy as np
def f(x):
    return np.cos(x + m.pi/4)

x = np.linspace(-5,9,100)
y = np.sin(3*x)
plt.figure()
plt.plot(x,y)
plt.grid()
# Out:
# El punto crítico está en [-0.785398163397448, 2.35619449019235]

# %% [markdown]
# ## Graficar funciones

# %%
import numpy as np

def f(x):
    return 2*x + 1
        
def g(x):
    return -x + 4

def z(x):
    return x**2

x = np.linspace(-9,9,100)
y = g(x)
plt.figure()

x2 = np.linspace(-9,9,100)
y2 = z(x)
plt.figure()


x3 = np.linspace(-9,9,100)
y3 = f(x)
plt.figure()

plt.plot(x, y, x2, y2, x3, y3)

# %%
def f(x):
    return np.sin(x)

def g(x):
    return np.cos(x)

x = np.linspace(-9,9,100)
y = f(x)
plt.figure()

x2 = np.linspace(-9,9,100)
y2 = g(x)
plt.figure()

plt.plot(x,y,x2,y2)

# %% [markdown]
# ## 3. Crear función

# %%
import math as m
import matplotlib.pyplot as plt
import numpy as np

def f(x):
    return np.sin(a*x)
a = 1

x = np.linspace(0,2*m.pi,1000)
y = f(x)
plt.figure()

def g(x):
    return np.sin(a*x)
a = 2

x2 = np.linspace(0,2*m.pi,1000)
y2 = f(x)
plt.figure()


def z(x):
    return np.sin(a*x)
a = 3

x3 = np.linspace(0,2*m.pi,1000)
y3 = f(x)
plt.figure()
plt.plot(x, y, x2, y2, x3, y3)
plt.grid()
